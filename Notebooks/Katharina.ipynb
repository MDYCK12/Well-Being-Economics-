# %%
#have functions that the page can call; think about limitations
#raw data = spreadshit, #transforming:bigquery, #streamlit 
#from bigquery, we need
#df_IMF is the Dataframe with only selected columns 
#Indicators from IMF 
#    'Gross domestic product (GDP) per capita, current prices, U.S. dollars': 'GDP per capita (adjusted for purchasing power parity)',
#   'Gross national savings, Percent of GDP': 'National savings (% GDP)',
#   'All Items, Consumer price index (CPI), End-of-period (EoP)': 'Inflation (CPI, %))',
#   'Unemployment rate': 'Unemployment levels (%)'

# %%
# !pip3 install pandas
# Out:
# zsh:1: command not found: pip

# %%
import pandas as pd

# %%
# !pip3 install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit
#   Downloading streamlit-1.50.0-py3-none-any.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 4.4 MB/s eta 0:00:01
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.3.3)
# Collecting cachetools<7,>=4.0
#   Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Collecting pyarrow>=7.0
#   Downloading pyarrow-21.0.0-cp39-cp39-macosx_12_0_arm64.whl (31.2 MB)
#      |████████████████████████████████| 31.2 MB 1.1 MB/s eta 0:00:011
# Collecting pydeck<1,>=0.8.0b4
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 34.0 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: packaging<26,>=20 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from streamlit) (25.0)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from streamlit) (6.5.2)
# Collecting tenacity<10,>=8.1.0
#   Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting requests<3,>=2.27
#   Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 10.3 MB/s eta 0:00:01
# Collecting blinker<2,>=1.5.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting protobuf<7,>=3.20
#   Downloading protobuf-6.33.1-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
#      |████████████████████████████████| 427 kB 1.1 MB/s eta 0:00:01
# Collecting pillow<12,>=7.1.0
#   Downloading pillow-11.3.0-cp39-cp39-macosx_11_0_arm64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 5.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy<3,>=1.23 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from streamlit) (2.0.2)
# Collecting toml<2,>=0.10.1
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting click<9,>=7.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 26.3 MB/s eta 0:00:01
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 22.8 MB/s eta 0:00:01
# Collecting altair!=5.4.0,!=5.4.1,<6,>=4.0
#   Downloading altair-5.5.0-py3-none-any.whl (731 kB)
#      |████████████████████████████████| 731 kB 50.9 MB/s eta 0:00:01
# Collecting jsonschema>=3.0
#   Downloading jsonschema-4.25.1-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 21.1 MB/s eta 0:00:01
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 32.1 MB/s eta 0:00:01
# Collecting narwhals>=1.14.2
#   Downloading narwhals-2.12.0-py3-none-any.whl (425 kB)
#      |████████████████████████████████| 425 kB 44.8 MB/s eta 0:00:01
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 5.2 MB/s eta 0:00:011
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Downloading jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Downloading referencing-0.36.2-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Downloading rpds_py-0.27.1-cp39-cp39-macosx_11_0_arm64.whl (354 kB)
#      |████████████████████████████████| 354 kB 48.9 MB/s eta 0:00:01
# Collecting attrs>=22.2.0
#   Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 13.4 MB/s eta 0:00:01
# Requirement already satisfied: tzdata>=2022.7 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Collecting MarkupSafe>=2.0
#   Downloading markupsafe-3.0.3-cp39-cp39-macosx_11_0_arm64.whl (12 kB)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.15.0)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#      |████████████████████████████████| 129 kB 18.3 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 27.3 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 10.2 MB/s eta 0:00:01
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.4-cp39-cp39-macosx_10_9_universal2.whl (209 kB)
#      |████████████████████████████████| 209 kB 42.6 MB/s eta 0:00:01
# Installing collected packages: rpds-py, attrs, referencing, smmap, MarkupSafe, jsonschema-specifications, urllib3, narwhals, jsonschema, jinja2, idna, gitdb, charset-normalizer, certifi, toml, tenacity, requests, pydeck, pyarrow, protobuf, pillow, gitpython, click, cachetools, blinker, altair, streamlit
# Successfully installed MarkupSafe-3.0.3 altair-5.5.0 attrs-25.4.0 blinker-1.9.0 cachetools-6.2.2 certifi-2025.11.12 charset-normalizer-3.4.4 click-8.1.8 gitdb-4.0.12 gitpython-3.1.45 idna-3.11 jinja2-3.1.6 jsonschema-4.25.1 jsonschema-specifications-2025.9.1 narwhals-2.12.0 pillow-11.3.0 protobuf-6.33.1 pyarrow-21.0.0 pydeck-0.9.1 referencing-0.36.2 requests-2.32.5 rpds-py-0.27.1 smmap-5.0.2 streamlit-1.50.0 tenacity-9.1.2 toml-0.10.2 urllib3-2.5.0
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import streamlit as st

# %%
import requests
# Out:
# /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
url_IMF = "https://docs.google.com/spreadsheets/d/1BV0koOEqQs580tEPGv9bpZYUfY8q8UTfZGTcEoK_VtQ/export?format=csv"

# %%
df_IMF_full = pd.read_csv(url_IMF,dtype='str')
df_IMF_full.head()
# Out:
#               DATASET   SERIES_CODE OBS_MEASURE  \
# 0  IMF.RES:WEO(9.0.0)      LIE.LE.A   OBS_VALUE
# 1  IMF.RES:WEO(9.0.0)      CAN.LE.A   OBS_VALUE
# 2  IMF.RES:WEO(9.0.0)  HND.NGDPPC.A   OBS_VALUE
# 3  IMF.RES:WEO(9.0.0)      HND.LP.A   OBS_VALUE
# 4  IMF.RES:WEO(9.0.0)      BHS.LP.A   OBS_VALUE
#
#                           COUNTRY  \
# 0  Liechtenstein, Principality of
# 1                          Canada
# 2                        Honduras
# 3                        Honduras
# 4                    Bahamas, The
#
#                                            INDICATOR FREQUENCY     SCALE  \
# 0  Employed persons, Persons for countries / Inde...    Annual  Millions
# 1  Employed persons, Persons for countries / Inde...    Annual  Millions
# 2  Gross domestic product (GDP), Current prices, ...    Annual     Units
# 3  Population, Persons for countries / Index for ...    Annual  Millions
# 4  Population, Persons for countries / Index for ...    Annual  Millions
#
#   DECIMALS_DISPLAYED FUNCTIONAL_CAT INT_ACC_ITEM  ...       2021       2022  \
# 0              Three            NaN          NaN  ...      0.041      0.043
# 1              Three            NaN          NaN  ...     18.973     19.748
# 2              Three            NaN          NaN  ...  66813.898  74749.009
# 3              Three            NaN          NaN  ...     10.117     10.294
# 4              Three            NaN          NaN  ...      0.394      0.399
#
#         2023       2024       2025        2026        2027        2028  \
# 0      0.043      0.044      0.045       0.046         NaN         NaN
# 1     20.341     20.723     21.009       21.08         NaN         NaN
# 2  80686.569  86300.122  95066.366  100495.041  106338.384  112815.742
# 3     10.475     10.659     10.846      11.037      11.231      11.428
# 4      0.404      0.408      0.413       0.417       0.421       0.425
#
#          2029        2030
# 0         NaN         NaN
# 1         NaN         NaN
# 2  119722.508  126957.554
# 3      11.629      11.833
# 4       0.429       0.434
#
# [5 rows x 116 columns]

# %%
#creating a sub-Table with the Data / Indicators that are relevant for our Analysis.
df_IMF = df_IMF_full[["SERIES_CODE", "COUNTRY", "INDICATOR", "FREQUENCY", "SCALE", "PRICES", "UNIT", "TOPIC", "1980","1981","1982","1983","1984","1985","1986","1987", "1988", "1989", "1990","1991","1992", "1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022","2023","2024","2025","2026","2027","2028","2029","2030" ]]

df_IMF.head()
# Out:
#     SERIES_CODE                         COUNTRY  \
# 0      LIE.LE.A  Liechtenstein, Principality of
# 1      CAN.LE.A                          Canada
# 2  HND.NGDPPC.A                        Honduras
# 3      HND.LP.A                        Honduras
# 4      BHS.LP.A                    Bahamas, The
#
#                                            INDICATOR FREQUENCY     SCALE  \
# 0  Employed persons, Persons for countries / Inde...    Annual  Millions
# 1  Employed persons, Persons for countries / Inde...    Annual  Millions
# 2  Gross domestic product (GDP), Current prices, ...    Annual     Units
# 3  Population, Persons for countries / Index for ...    Annual  Millions
# 4  Population, Persons for countries / Index for ...    Annual  Millions
#
#            PRICES               UNIT                         TOPIC      1980  \
# 0             NaN                NaN                    Employment       NaN
# 1             NaN                NaN                    Employment     10.98
# 2  Current prices  Domestic currency  Gross domestic product (GDP)  2160.861
# 3             NaN                NaN                    Population     3.673
# 4             NaN                NaN                    Population     0.211
#
#        1981  ...       2021       2022       2023       2024       2025  \
# 0       NaN  ...      0.041      0.043      0.043      0.044      0.045
# 1    11.304  ...     18.973     19.748     20.341     20.723     21.009
# 2  2133.804  ...  66813.898  74749.009  80686.569  86300.122  95066.366
# 3      3.79  ...     10.117     10.294     10.475     10.659     10.846
# 4     0.215  ...      0.394      0.399      0.404      0.408      0.413
#
#          2026        2027        2028        2029        2030
# 0       0.046         NaN         NaN         NaN         NaN
# 1       21.08         NaN         NaN         NaN         NaN
# 2  100495.041  106338.384  112815.742  119722.508  126957.554
# 3      11.037      11.231      11.428      11.629      11.833
# 4       0.417       0.421       0.425       0.429       0.434
#
# [5 rows x 59 columns]

# %%
#Table with all Countries 
df_IMF

# %%
Germany_Data_full = df_IMF[df_IMF['COUNTRY'] == 'Germany']
Germany_Data_full.head()
# Out:
#        SERIES_CODE  COUNTRY  \
# 257   DEU.NGDP_D.A  Germany
# 260      DEU.GGX.A  Germany
# 262  DEU.PCPIPCH.A  Germany
# 266   DEU.GGXWDN.A  Germany
# 267    DEU.NGDPD.A  Germany
#
#                                              INDICATOR FREQUENCY     SCALE  \
# 257  Gross domestic product (GDP), Price deflator, ...    Annual     Units
# 260  Expenditure, General government, Domestic curr...    Annual  Billions
# 262  All Items, Consumer price index (CPI), Period ...    Annual     Units
# 266    Net debt, General government, Domestic currency    Annual  Billions
# 267  Gross domestic product (GDP), Current prices, ...    Annual  Billions
#
#              PRICES               UNIT                         TOPIC     1980  \
# 257             NaN              Index  Gross domestic product (GDP)   43.069
# 260             NaN  Domestic currency                 Fiscal sector      NaN
# 262             NaN            Percent               Consumer prices    5.447
# 266             NaN  Domestic currency                 Fiscal sector      NaN
# 267  Current prices          US dollar  Gross domestic product (GDP)  856.833
#
#         1981  ...      2021      2022      2023      2024      2025      2026  \
# 257   44.907  ...   102.694   109.283   116.598   120.224   123.034   125.362
# 260      NaN  ...  1865.819  1939.208  2031.433  2139.717  2239.054  2346.945
# 262    6.324  ...     3.212     8.666      6.03     2.489     2.114     1.756
# 266      NaN  ...  1701.826  1830.877  1935.642  2050.937  2162.902  2316.618
# 267  720.895  ...  4358.147  4204.327  4563.523  4684.182  5013.574  5328.184
#
#          2027      2028      2029      2030
# 257   127.825   130.572   133.402   136.368
# 260  2453.825  2538.574  2624.962  2707.148
# 262     2.011     2.094      2.17     2.177
# 266  2507.124   2704.68  2908.711  3118.692
# 267  5498.618  5674.354  5848.295  6013.749
#
# [5 rows x 59 columns]

# %%
pd.set_option('display.max_colwidth', None)

# %%
#clear the table for the Countries we selected prior
#Data not really available for Japan, USA, Germany, UK, Denmark, 
df_IMF_select = df_IMF[df_IMF["COUNTRY"].isin([
    "Japan", "China", "Indonesia",
    "Germany", "UK", "Bosnia & Herzegovina", "Denmark",
    "South Africa", "Ghana", "Ivory Coast",
    "US", "Chile", "Costa Rica", "Paraguay"
])]

df_IMF_new
# Out:
#            SERIES_CODE  COUNTRY  \
# 139     DNK.GGR_NGDP.A  Denmark
# 142    DNK.BCA_NGDPD.A  Denmark
# 256     DNK.GGX_NGDP.A  Denmark
# 257       DEU.NGDP_D.A  Germany
# 258      DNK.GGXONLB.A  Denmark
# ...                ...      ...
# 8036  JPN.NGAP_NPGDP.A    Japan
# 8074     GHA.TX_RPCH.A    Ghana
# 8135         GHA.GGR.A    Ghana
# 8163     GHA.GGXONLB.A    Ghana
# 8167      GHA.GGXCNL.A    Ghana
#
#                                                                                INDICATOR  \
# 139                                          Revenue, General government, Percent of GDP
# 142                          Current account balance (credit less debit), Percent of GDP
# 256                                      Expenditure, General government, Percent of GDP
# 257                                  Gross domestic product (GDP), Price deflator, Index
# 258   Primary net lending (+) / net borrowing (-), General government, Domestic currency
# ...                                                                                  ...
# 8036                                                Output gap, Percent of potential GDP
# 8074          Exports of goods and services, Volume, Free on board (FOB), Percent change
# 8135                                      Revenue, General government, Domestic currency
# 8163  Primary net lending (+) / net borrowing (-), General government, Domestic currency
# 8167          Net lending (+) / net borrowing (-), General government, Domestic currency
#
#      FREQUENCY     SCALE  PRICES               UNIT  \
# 139     Annual     Units     NaN            Percent
# 142     Annual     Units     NaN            Percent
# 256     Annual     Units     NaN            Percent
# 257     Annual     Units     NaN              Index
# 258     Annual  Billions     NaN  Domestic currency
# ...        ...       ...     ...                ...
# 8036    Annual     Units     NaN            Percent
# 8074    Annual     Units  Volume            Percent
# 8135    Annual  Billions     NaN  Domestic currency
# 8163    Annual  Billions     NaN  Domestic currency
# 8167    Annual  Billions     NaN  Domestic currency
#
#                                      TOPIC    1980     1981  ...     2021  \
# 139                          Fiscal sector  49.034   49.235  ...   53.826
# 142   Balance of payments; Current account  -3.374   -3.051  ...    8.548
# 256                          Fiscal sector  52.718   56.027  ...   49.706
# 257           Gross domestic product (GDP)  43.069   44.907  ...  102.694
# 258                          Fiscal sector  -9.643  -18.626  ...   94.476
# ...                                    ...     ...      ...  ...      ...
# 8036          Gross domestic product (GDP)  -5.672   -4.393  ...   -1.616
# 8074                               Exports   -13.6    -60.4  ...  -10.307
# 8135                         Fiscal sector     NaN      NaN  ...   70.097
# 8163                         Fiscal sector     NaN   -0.001  ...  -22.028
# 8167                         Fiscal sector  -0.001   -0.001  ...   -55.55
#
#          2022     2023     2024     2025     2026     2027     2028     2029  \
# 139    48.478   50.828   51.788   50.768       50    49.63   49.794   49.897
# 142    11.163   11.005   12.193   12.235   11.661   11.401   11.264   11.224
# 256    45.089   47.398   47.329   48.967   49.633   49.735   49.982   50.336
# 257   109.283  116.598  120.224  123.034  125.362  127.825  130.572  133.402
# 258    86.284   71.715  108.533   30.416   -7.375  -23.222  -26.876  -36.646
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 8036   -0.881    0.233     0.24      0.3     0.16    0.121    0.017      NaN
# 8074    3.797   -6.058     2.32   -2.206    5.231    0.913    4.384    8.878
# 8135   96.651  134.672  186.593  227.504  272.028  310.084  350.015  396.664
# 8163  -26.558   -2.829  -38.877   20.478   23.938   27.092   30.703   34.795
# 8167  -72.245  -29.884  -86.027  -38.457  -30.419   -30.75  -39.386  -48.601
#
#          2030
# 139    49.897
# 142    11.194
# 256    50.442
# 257   136.368
# 258   -41.779
# ...       ...
# 8036   -0.048
# 8074    3.356
# 8135  449.164
# 8163   26.267
# 8167  -66.009
#
# [379 rows x 59 columns]

# %%
#get data to big query
#function for getting the data 
#

# %%
# !pip3 install plotly.express
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting plotly.express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Collecting statsmodels>=0.9.0
#   Downloading statsmodels-0.14.5-cp39-cp39-macosx_11_0_arm64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 4.2 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.11 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from plotly.express) (2.0.2)
# Collecting scipy>=0.18
#   Downloading scipy-1.13.1-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 5.5 MB/s eta 0:00:011
# Collecting patsy>=0.5
#   Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 11.0 MB/s eta 0:00:01
# Collecting plotly>=4.1.0
#   Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 3.6 MB/s eta 0:00:011
# Requirement already satisfied: pandas>=0.20.0 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from plotly.express) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from plotly>=4.1.0->plotly.express) (2.12.0)
# Requirement already satisfied: packaging in /Users/katharinajeczawitz/Library/Python/3.9/lib/python/site-packages (from plotly>=4.1.0->plotly.express) (25.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.15.0)
# Installing collected packages: scipy, patsy, statsmodels, plotly, plotly.express
# Successfully installed patsy-1.0.2 plotly-6.5.0 plotly.express-0.4.1 scipy-1.13.1 statsmodels-0.14.5
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import plotly_express as px

# %%
# Rename Indicators for better visualization

indicator_map = {
    'Gross domestic product (GDP) per capita, current prices, U.S. dollars': 'GDP per capita (adjusted for purchasing power parity)',
    'Gross national savings, Percent of GDP': 'National savings (% GDP)',
    'All Items, Consumer price index (CPI), End-of-period (EoP)': 'Inflation (CPI, %))',
    'Unemployment rate': 'Unemployment levels (%)'
}

df_countries_analysis['INDICATOR'] = df_countries_analysis['INDICATOR'].map(indicator_map)

df_countries_analysis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 10
#       1 # Rename Indicators for better visualization
#       3 indicator_map = {
#       4     'Gross domestic product (GDP) per capita, current prices, U.S. dollars': 'GDP per capita (adjusted for purchasing power parity)',
#       5     'Gross national savings, Percent of GDP': 'National savings (% GDP)',
#       6     'All Items, Consumer price index (CPI), End-of-period (EoP)': 'Inflation (CPI, %))',
#       7     'Unemployment rate': 'Unemployment levels (%)'
#       8 }
# ---> 10 df_countries_analysis['INDICATOR'] = df_countries_analysis['INDICATOR'].map(indicator_map)
#      12 df_countries_analysis
#
# NameError: name 'df_countries_analysis' is not defined

# %%
pd.read_csv

#birthrate = no 2024 data; health: data from 2000 until 2024; GINI INDEX:ab 2000
